# %%
import pickle
import torch

model = pickle.load(open("model.pkl", "rb"))

# %%
model
# Out:
# tensor([[ 0.0129,  0.8562, -0.0022, -0.0933]], requires_grad=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
POLY = 4 # cubid
SIZE=2000
X = torch.unsqueeze(torch.linspace(-np.pi, np.pi, SIZE), axis=1)
data = torch.cat([X.pow(i) for i in range(POLY)], axis=1)
Y_pred = data@model.T
plt.plot(X, Y_pred.detach().numpy())
plt.show()
